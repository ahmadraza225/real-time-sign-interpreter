# %% [markdown]
# # ASL Landmark EDA + Training Walkthrough\n\n1. Explore class distribution for A–Z.\n2. Visualize MediaPipe landmarks over sample frames.\n3. Run feature extraction and baseline model training scripts.

# %%
from pathlib import Path\nDATASET_ROOT = Path('../backend/data/asl_alphabet_train')\nDATASET_ROOT

# %%
# Example: !python ../backend/scripts/train_models.py --dataset ../backend/data/asl_alphabet_train
